# %%
#FUNCIONES DE ACTIVACIÓN Y COSTE PARA REDES NEURONALES MULTICAPA
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
from scipy.special import expit,softmax

class function(object):
    def __init__(self,funcion,derivative=None,rand_init=(0,1)):
        self.F=funcion
        self.D=derivative
        self.Rand_init=rand_init

lineal=function(funcion=lambda x:x, derivative=lambda x:1, rand_init=(-1,1))
sigm=function(funcion=lambda x: expit(x), derivative=lambda x: expit(x)*(1-expit(x)), rand_init=(0,1))
tanh1=function(funcion=lambda x:np.tanh(x), derivative=lambda x:1-np.tanh(x)**2, rand_init=(-1,1))
relu=function(funcion=lambda x: np.maximum(0, x), derivative=lambda x: np.where(x<=0,0,1), rand_init=(0,1))
softmaxf=function(funcion=lambda x: softmax(x), derivative=lambda x:softmax(x)*(1-softmax(x)), rand_init=(0,1))
tanh=function(funcion=lambda x:(np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x)),
              derivative=lambda x:1-((np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x)))**2,
              rand_init=(-1,1))
Funciones={"relu":relu, "sigm":sigm, "relu":relu, "tanh":tanh, "tanh1":tanh1, "lineal":lineal, "softmax":softmaxf}

mse=function(funcion=lambda Yp, Yr: np.mean((Yp - Yr) ** 2) , derivative=lambda Yp, Yr: (Yp - Yr))
cross_entropy=function(funcion=lambda yscore,yreal:-np.sum(yreal*np.log(yscore))/yscore.shape[0],
                       derivative=lambda yscore,yreal:yscore-yreal)
Loss={"mse":mse, "cross_entropy":cross_entropy}

# %%
# CARGA Y TRATAMIENTO DE DATOS
import pandas as pd
from sklearn.model_selection import train_test_split

# # 1: TIC-TAC-TOE
# df = pd.read_csv("datasets/tic_tac_toe_dataset.csv")
# df = df.replace(['x', 'b', 'o'], [0, 0.5, 1]) # Numeración de los estados de las carillas
# Y = pd.get_dummies(df['class']).to_numpy()
# X = df.drop('class', axis=1).to_numpy()


# # 2: GENDER VOICE
# df = pd.read_csv("datasets/gender_voice_dataset.csv")
# Y = pd.get_dummies(df.iloc[:, -1]).to_numpy()
# df = df.iloc[:, :-1]
# X = (df-df.min())/(df.max()-df.min()).to_numpy()
# # ===================
# # EXPLOTA EN EL TRAIN
# # ===================

# 3: 
df = pd.read_csv("datasets/breast_cancer_dataset.csv", header=None)
df = df[df.iloc[:,5] > -100000] # Filtro para los valores extraños
Y = pd.get_dummies(df.iloc[:, -1]).to_numpy()
df = df.iloc[:, :-1] / 10
X = df.to_numpy()
print(X)

# x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
# # print(X, x_train, x_test, Y, y_train, y_test)
# print(np.shape(X), np.shape(x_train), np.shape(x_test))
# print(np.shape(Y), np.shape(y_train), np.shape(y_test))
# Out:
# [[0.5 0.1 0.1 ... 0.3 0.1 0.1]
#  [0.5 0.4 0.4 ... 0.3 0.2 0.1]
#  [0.3 0.1 0.1 ... 0.3 0.1 0.1]
#  ...
#  [0.3 0.1 0.2 ... 0.3 0.1 0.1]
#  [0.4 0.1 0.1 ... 0.2 0.1 0.1]
#  [0.8 0.4 0.4 ... 0.2 0.5 0.2]]

# %%
# CLASE DE LA CAPA DE LA RED
from IPython.display import clear_output
import time

class neural_layer(object):
    def __init__(self, n_conn, n_neur, activation="relu"):
        self.act = Funciones[activation]
        self.activation=activation
        self.random=self.act.Rand_init  
        self.shape=(n_conn,n_neur)
        self.Initialize()
        
    def show(self,Full=False):
        print(f"Pesos shape:{np.shape(self.W)} bias shape:{np.shape(self.b)} Activation:{self.activation}")
        print(f"Activation:{self.activation}, Random:{self.random}")
        print("______________________")
        if Full:
            print(f"Pesos:")
            print(self.W)
            print("#####")
            print(f"Bias:")
            print(self.b)
            
    def Initialize(self):
        self.b = np.random.uniform(*self.random,(1, self.shape[1]))      
        self.W = np.random.uniform(*self.random,self.shape)
        
            
#CLASE RED NEURONAL MULTICAPA        
class Neural_Net(object):
    def __init__(self,Input,loss):
        self.loss = Loss[loss]
        self.Funcion_Loss=loss
        self.Input=Input
        self.NN=None;
              
    def Add_Layer(self,Num_neurons, function):
        if self.NN is None:
            self.NN=[]
            self.NN.append(neural_layer(self.Input,Num_neurons,function))
        else:
            _,L_input=np.shape(self.NN[-1].W)
            self.NN.append(neural_layer(L_input,Num_neurons,function))
            
    def Show_Model(self, Full=False):
        print(f"Input shape:{self.Input}, Loss: {self.Funcion_Loss}")
        for i,L in enumerate(self.NN):
            print(F"Layer_{i}:")
            L.show(Full)
            
            
    # fucnción de predicción (fordware pass)    
    def Predict(self,X):  
      #sólo podemos pasar Numpy  
      sx=np.shape(X)
      X=X.reshape(1,sx[0])
      if self.NN is None:
          print("error in Predict Method ( not NEURAL network available)")
          return 0
        
      out = [(None, X)] #primer data necesario
      # Forward pass
      for l, layer in enumerate(self.NN):
          z = out[-1][1] @ self.NN[l].W + self.NN[l].b
          a = self.NN[l].act.F(z)
          out.append((z, a))
      return out[-1][1]
    
    
    # función retropropagación del error
    def _backward_pass(self, X, Y,lr=0.01):
      sx=np.shape(X)
      sy=np.shape(Y)   
      X=X.reshape(1,sx[0])
      Y=Y.reshape(1,sy[0])

      # Forward pass
      out = [(None, X)] #primer data necesario
      for l, layer in enumerate(self.NN):
            z = out[-1][1] @ self.NN[l].W + self.NN[l].b
            a = self.NN[l].act.F(z)
            out.append((z, a))

      # Backward pass 
      deltas = []
      for l in reversed(range(0, len(self.NN))):
        z = out[l+1][0]
        a = out[l+1][1]
        if l == len(self.NN) - 1:
            deltas.insert(0, self.loss.D(a, Y) * self.NN[l].act.D(a))
        else:
            deltas.insert(0, deltas[0] @ _W.T * self.NN[l-1].act.D(a))
        _W = self.NN[l].W #los pesos en la capa superior
 
        # Gradient descent
        self.NN[l].b = self.NN[l].b - (deltas[0]* lr)
        self.NN[l].W = self.NN[l].W - (lr * (out[l][1].T @ deltas[0]))
      return out[-1][1]

    # función de entrenamiento de la red
    def Train(self,X,Y,lr=0.01,epoch=10,batch_size=1):
        H_loss = []
        H_acc=[]
        
        # inicializamos las capas neuronales a valores ramdom del rango de la función
        for Layer in self.NN:
            Layer.Initialize()
            
        for i in range(epoch):
            account=0
            epoch_Loss=0
            epoch_Acc=0
            # Entrenemos a la red! con el dataset de validación
            for j in range(len(X)):
                pY = self._backward_pass(X[j,:], Y[j,:],lr)
                epoch_Loss+=self.loss.F(pY[0],Y[j,:])
                if (Y[j,:]==np.round(pY)).all():
                    epoch_Acc+=1
            H_acc.append(epoch_Acc/len(Y)*100)    
            H_loss.append(epoch_Loss/len(Y))
            
            #imprimimos por pantalla resultados
            print("Epoch={}, Accurary={} Loss={}".format(i,round(H_acc[-1],3),round(H_loss[-1],7)))
            clear_output(wait=True)
        print("Epoch={}, Accuracy={} Loss={}".format(i,round(H_acc[-1],3),round(H_loss[-1],7)))
        return H_loss,H_acc

    
# VISUALIZACIÓN Y TEST
def Show_Loss_Acc(H_loss,H_acc):
    plt.plot(range(len(H_loss)), H_loss,"tab:blue")
    plt.ylabel("loss function ")
    plt.xlabel("EPOCH NUMBER")
    plt.show()
    plt.plot(range(len(H_acc)), H_acc, "tab:red")
    plt.ylabel("ACCURACY")
    plt.xlabel("EPOCH NUMBER")
    plt.show()
       
def print_predict(neural_net,X,Y):
    for i in range(len(X)):
        sal_float=neural_net.Predict(X[i])
        sal=np.round(sal_float)
        
        if (Y[i]==np.round(sal)).all():
            print("Input:{}-- Real:{} predict: {} predict_float:{}".format(X[i],Y[i],sal,np.round(sal_float,2)))
        else:
            print("\x1b[31m Input:{}-- Real:{} predict: {} predict_float:{}\x1b[0m".format(X[i],Y[i],sal,np.round(sal_float,2)))

# %%
#DEFINIMOS LOS MODELOs
_, x_input = x_train.shape
_, y_output = y_train.shape
print(x_input, y_output)

def Model_1_1():
    red=Neural_Net(Input=x_input,loss="cross_entropy")
    red.Add_Layer(10,"relu")
    red.Add_Layer(y_output,"softmax")
    return red

def Model_1_2():
    red=Neural_Net(Input=x_input,loss="cross_entropy")
    red.Add_Layer(18,"sigm")
    red.Add_Layer(y_output,"softmax")
    return red

def Model_2_1():
    red=Neural_Net(Input=x_input,loss="cross_entropy")
    red.Add_Layer(20,"relu")
    red.Add_Layer(y_output,"softmax")
    return red

def Model_2_2():
    red=Neural_Net(Input=x_input,loss="cross_entropy")
    red.Add_Layer(25,"tanh")
    red.Add_Layer(y_output,"softmax")
    return red

def Model_3_1():
    red=Neural_Net(Input=x_input,loss="cross_entropy")
    red.Add_Layer(20,"relu")
    red.Add_Layer(6,"sigm")
    red.Add_Layer(y_output,"softmax")
    return red

def Model_3_2():
    red=Neural_Net(Input=x_input,loss="cross_entropy")
    red.Add_Layer(30,"relu")
    red.Add_Layer(y_output,"softmax")
    return red

def Model_BUENA():
    red=Neural_Net(Input=x_input,loss="cross_entropy")
    red.Add_Layer(16,"sigm")
    red.Add_Layer(24,"tanh")
    red.Add_Layer(8,"relu")
    red.Add_Layer(y_output,"softmax")
    return red
# Out:
# 9 2

# %%
cnn=Model_3_2()
cnn.Show_Model()
#cnn.Show_Model(True)
# Out:
# Input shape:9, Loss: cross_entropy
# Layer_0:
# Pesos shape:(9, 30) bias shape:(1, 30) Activation:relu
# Activation:relu, Random:(0, 1)
# ______________________
# Layer_1:
# Pesos shape:(30, 2) bias shape:(1, 2) Activation:softmax
# Activation:softmax, Random:(0, 1)
# ______________________

# %%
loss,accuracy=cnn.Train(x_train, y_train, 0.2, 150)
Show_Loss_Acc(loss, accuracy)
# Out:
# Epoch=149, Accuracy=90.519 Loss=nan

# %%
print_predict(cnn, x_test, y_test)
# Out:
# Input:[1 1 1 1 2 1 3 2 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[6 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 2 2 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 1 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[2 1 2 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 8 10  3  2  6  4  3 10  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 1 1 1 3 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 4 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  6  4  1  3  4  3  2  3]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  5  7  4  4 10  8  9  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 1 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  8  8  4 10 10  8  1  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  6  4  3 10 10  9 10  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[6 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 4  8  7 10  4 10  7  5  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  5  7  3  3  7  3  3  8]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 1 1 2 2 3 3 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 1 2 1 2]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 3 1 1 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  8  8  2  3  4  8  7  8]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 3 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 7  5  3  7  4 10  7  5  5]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 5 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[2 1 1 1 2 1 2 2 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 2 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 1 1 2 1 2 2 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[9 5 8 1 2 3 2 1 5]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[2 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[7 2 4 1 3 4 3 3 1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 1 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 2 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[3 4 5 2 6 8 4 1 1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[5 3 3 4 2 4 3 4 1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[3 7 7 4 4 9 4 8 1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 2 2 3 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 2 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  1  1  1  2 10  5  4  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[2 2 2 1 1 1 7 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  4  5  5  5 10  4  1  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10 10 10 10 10  1  8  8  8]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 3 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 5  3  5  5  3  3  4 10  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[6 9 7 5 5 8 4 2 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  3  5  1 10  5  3 10  2]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 7 7 1 5 8 3 4 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 9  6  9  2 10  6  2  9 10]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 7  4  4  3  4 10  6  9  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 3 3 2 3 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 4 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 2 2 2 1 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10 10 10  3 10  8  8  1  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 2 1 1 2 2 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10 10  8  6  4  5  8 10  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 9  8  8  5  6  2  4 10  4]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  3  3  1  2 10  7  6  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 1 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 3 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 1  5  8  6  5  8  7 10  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 2 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 5  6  6  8  6 10  4 10  4]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 4 4 4 6 5 7 3 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 1 1 1 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 3 2 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 1  4  3 10  4 10  5  6  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 2 1 3 1 1 7]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 3 2 2 3 1 1 2 3]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[6 8 7 8 6 8 8 9 1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[5 3 3 1 3 3 3 3 3]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[9 5 5 2 2 2 5 1 1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 7  4  5 10  2 10  3  8  2]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 5 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 1 1 1 2 2 3 2 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 5 5 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 2 3 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 3 1 1 2 1 4 8 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 8  4  4  1  6 10  2  5  2]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[2 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 3 2 1 3 1 3 6 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 1 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 6 10  7  7  6  4  8 10  2]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  8 10  1  3 10  5  1  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 1 4 1 2 1 3 2 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[1 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[2 1 1 1 2 1 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 8 10 10  8  7 10  9  7  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[6 8 7 5 6 8 8 9 2]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 2 2 2 2 1 4 2 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 5  8  9  4  3 10  7  1  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 9 10 10  1 10  8  3  3  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 1 2 1 2 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[5 2 1 1 2 1 1 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[ 1  6  8 10  8 10  5  7  1]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[4 3 2 1 3 1 2 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
# Input:[3 3 2 1 2 3 3 1 1]-- Real:[1 0] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
#  Input:[10  8 10 10  6  1  3  1 10]-- Real:[0 1] predict: [[1. 0.]] predict_float:[[0.65 0.35]]
