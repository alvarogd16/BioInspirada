# %% [markdown]
# ANN Binaria con dataset Tic-tac-toe

# %%
# Funciones para el procesamiento de los datos

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
Min_Max = preprocessing.MinMaxScaler()
Ordinal =preprocessing.OrdinalEncoder()


def one_hot_cols(df,cols_to_one):
    one_hot=pd.get_dummies(df,cols_to_one,columns=cols_to_one)
    return one_hot


def fit_cols(df, cols_to_fit,fit_function ):
    for col in cols_to_fit:
        df[col] = pd.DataFrame(fit_function.fit_transform(pd.DataFrame(df[col])),columns=[col])
    return df


def split_Dataset(mypandas, cols_for_Y,size=0.2,state=1):
    
    X =  mypandas.drop(cols_for_Y, axis=1)
    Y = mypandas[cols_for_Y]
    X.head()
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=size, random_state=state)
    return X_train.to_numpy(), X_test.to_numpy(), Y_train.to_numpy(), Y_test.to_numpy()

# %%
data_origin = pd.read_csv(r'../3_Normalización/datasets/tic_tac_toe_dataset.csv')
dataset = fit_cols(data_origin, list(data_origin.columns), Ordinal)
dataset = fit_cols(dataset, dataset.columns, Min_Max)
# dataset.head(20)

# %%
X_train, X_test, Y_train, Y_test = split_Dataset(dataset,['class'])
print(np.shape(X_train),np.shape(Y_train))
print(np.shape(X_test),np.shape(Y_test))
# Out:
# (766, 9) (766, 1)
# (192, 9) (192, 1)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.python.keras.utils import np_utils
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop


import matplotlib.pyplot as plt


def Show_History(History):
    # summarize history for accuracy
    plt.plot(History.history['accuracy'])
    plt.plot(History.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(History.history['loss'])
    plt.plot(History.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

np.random.seed(7)



Adam=optimizers.Adam(lr=0.05)
Sgd=optimizers.SGD(lr=0.01)

# %%
def Model1():
    model = Sequential()
    model.add(Dense(15,input_dim=9,activation='relu'))
    model.add(Dense(8,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def Model2():
    model = Sequential()
    model.add(Dense(15,input_dim=9,activation='relu'))
    model.add(Dense(8,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
    

M=Model2()

# %%
History=M.fit(X_train, Y_train, epochs=100, batch_size=4, validation_data=(X_test,Y_test))
Show_History(History)
# Out:
# Epoch 1/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.7139 - accuracy: 0.4618 - val_loss: 0.6438 - val_accuracy: 0.6510
# Epoch 2/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6497 - accuracy: 0.6376 - val_loss: 0.6215 - val_accuracy: 0.6510
# Epoch 3/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6384 - accuracy: 0.6403 - val_loss: 0.6172 - val_accuracy: 0.6510
# Epoch 4/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6390 - accuracy: 0.6514 - val_loss: 0.6169 - val_accuracy: 0.6562
# Epoch 5/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6155 - accuracy: 0.6659 - val_loss: 0.6105 - val_accuracy: 0.6667
# Epoch 6/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6245 - accuracy: 0.6576 - val_loss: 0.6030 - val_accuracy: 0.6719
# Epoch 7/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6177 - accuracy: 0.6472 - val_loss: 0.5988 - val_accuracy: 0.6719
# Epoch 8/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6263 - accuracy: 0.6575 - val_loss: 0.5963 - val_accuracy: 0.6823
# Epoch 9/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6193 - accuracy: 0.6606 - val_loss: 0.5927 - val_accuracy: 0.6823
# Epoch 10/100
# 192/192 [==============================] - 1s 5ms/step - loss: 0.6205 - accuracy: 0.6583 - val_loss: 0.5893 - val_accuracy: 0.6875
# Epoch 11/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6014 - accuracy: 0.6860 - val_loss: 0.5795 - val_accuracy: 0.7031
# Epoch 12/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5996 - accuracy: 0.6482 - val_loss: 0.5764 - val_accuracy: 0.6875
# Epoch 13/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5953 - accuracy: 0.6975 - val_loss: 0.5749 - val_accuracy: 0.6823
# Epoch 14/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6004 - accuracy: 0.7014 - val_loss: 0.5706 - val_accuracy: 0.6927
# Epoch 15/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5677 - accuracy: 0.7133 - val_loss: 0.5668 - val_accuracy: 0.6823
# Epoch 16/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5902 - accuracy: 0.6958 - val_loss: 0.5561 - val_accuracy: 0.7344
# Epoch 17/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5782 - accuracy: 0.7033 - val_loss: 0.5576 - val_accuracy: 0.7188
# Epoch 18/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5639 - accuracy: 0.7415 - val_loss: 0.5511 - val_accuracy: 0.7292
# Epoch 19/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5881 - accuracy: 0.7018 - val_loss: 0.5477 - val_accuracy: 0.7396
# Epoch 20/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5601 - accuracy: 0.7362 - val_loss: 0.5421 - val_accuracy: 0.7500
# Epoch 21/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5564 - accuracy: 0.7265 - val_loss: 0.5442 - val_accuracy: 0.7448
# Epoch 22/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5402 - accuracy: 0.7489 - val_loss: 0.5472 - val_accuracy: 0.7448
# Epoch 23/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5532 - accuracy: 0.7447 - val_loss: 0.5396 - val_accuracy: 0.7396
# Epoch 24/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5432 - accuracy: 0.7340 - val_loss: 0.5339 - val_accuracy: 0.7396
# Epoch 25/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5253 - accuracy: 0.7745 - val_loss: 0.5249 - val_accuracy: 0.7760
# Epoch 26/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5029 - accuracy: 0.7934 - val_loss: 0.5378 - val_accuracy: 0.7500
# Epoch 27/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5329 - accuracy: 0.7620 - val_loss: 0.5288 - val_accuracy: 0.7552
# Epoch 28/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5116 - accuracy: 0.7868 - val_loss: 0.5232 - val_accuracy: 0.7396
# Epoch 29/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4923 - accuracy: 0.7998 - val_loss: 0.5161 - val_accuracy: 0.7708
# Epoch 30/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5221 - accuracy: 0.7641 - val_loss: 0.5262 - val_accuracy: 0.7500
# Epoch 31/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5060 - accuracy: 0.7654 - val_loss: 0.5102 - val_accuracy: 0.7656
# Epoch 32/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5133 - accuracy: 0.7635 - val_loss: 0.5175 - val_accuracy: 0.7448
# Epoch 33/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5514 - accuracy: 0.7191 - val_loss: 0.5032 - val_accuracy: 0.7656
# Epoch 34/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4810 - accuracy: 0.7829 - val_loss: 0.4988 - val_accuracy: 0.7604
# Epoch 35/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5070 - accuracy: 0.7644 - val_loss: 0.4904 - val_accuracy: 0.7812
# Epoch 36/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4803 - accuracy: 0.7807 - val_loss: 0.5017 - val_accuracy: 0.7552
# Epoch 37/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4771 - accuracy: 0.7892 - val_loss: 0.4930 - val_accuracy: 0.7708
# Epoch 38/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4803 - accuracy: 0.7756 - val_loss: 0.4879 - val_accuracy: 0.7760
# Epoch 39/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5223 - accuracy: 0.7511 - val_loss: 0.4921 - val_accuracy: 0.7500
# Epoch 40/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4664 - accuracy: 0.7803 - val_loss: 0.4892 - val_accuracy: 0.7812
# Epoch 41/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4798 - accuracy: 0.7920 - val_loss: 0.4852 - val_accuracy: 0.7760
# Epoch 42/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4409 - accuracy: 0.8180 - val_loss: 0.4716 - val_accuracy: 0.7969
# Epoch 43/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4799 - accuracy: 0.7863 - val_loss: 0.4782 - val_accuracy: 0.7604
# Epoch 44/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4738 - accuracy: 0.7833 - val_loss: 0.4684 - val_accuracy: 0.8021
# Epoch 45/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4590 - accuracy: 0.7898 - val_loss: 0.4667 - val_accuracy: 0.7917
# Epoch 46/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4875 - accuracy: 0.7701 - val_loss: 0.4635 - val_accuracy: 0.7917
# Epoch 47/100
# 192/192 [==============================] - 1s 5ms/step - loss: 0.4606 - accuracy: 0.7931 - val_loss: 0.4572 - val_accuracy: 0.8229
# Epoch 48/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4281 - accuracy: 0.8236 - val_loss: 0.4592 - val_accuracy: 0.8021
# Epoch 49/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4805 - accuracy: 0.7929 - val_loss: 0.4576 - val_accuracy: 0.8073
# Epoch 50/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4454 - accuracy: 0.7952 - val_loss: 0.4519 - val_accuracy: 0.7917
# Epoch 51/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4620 - accuracy: 0.8081 - val_loss: 0.4565 - val_accuracy: 0.7865
# Epoch 52/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4342 - accuracy: 0.8146 - val_loss: 0.4652 - val_accuracy: 0.7812
# Epoch 53/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4577 - accuracy: 0.7827 - val_loss: 0.4507 - val_accuracy: 0.8073
# Epoch 54/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4273 - accuracy: 0.8120 - val_loss: 0.4609 - val_accuracy: 0.7917
# Epoch 55/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4455 - accuracy: 0.8051 - val_loss: 0.4595 - val_accuracy: 0.7917
# Epoch 56/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4518 - accuracy: 0.7670 - val_loss: 0.4487 - val_accuracy: 0.7969
# Epoch 57/100
# 192/192 [==============================] - 0s 3ms/step - loss: 0.4694 - accuracy: 0.7872 - val_loss: 0.4657 - val_accuracy: 0.7812
# Epoch 58/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4257 - accuracy: 0.8074 - val_loss: 0.4371 - val_accuracy: 0.8125
# Epoch 59/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4448 - accuracy: 0.8084 - val_loss: 0.4397 - val_accuracy: 0.8073
# Epoch 60/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4517 - accuracy: 0.7994 - val_loss: 0.4475 - val_accuracy: 0.7917
# Epoch 61/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4261 - accuracy: 0.8054 - val_loss: 0.4323 - val_accuracy: 0.8125
# Epoch 62/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4557 - accuracy: 0.7776 - val_loss: 0.4394 - val_accuracy: 0.8073
# Epoch 63/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4260 - accuracy: 0.8223 - val_loss: 0.4302 - val_accuracy: 0.8073
# Epoch 64/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.3814 - accuracy: 0.8371 - val_loss: 0.4254 - val_accuracy: 0.8229
# Epoch 65/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4050 - accuracy: 0.8209 - val_loss: 0.4417 - val_accuracy: 0.8073
# Epoch 66/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4184 - accuracy: 0.8142 - val_loss: 0.4287 - val_accuracy: 0.8177
# Epoch 67/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4164 - accuracy: 0.8198 - val_loss: 0.4273 - val_accuracy: 0.8177
# Epoch 68/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4342 - accuracy: 0.8015 - val_loss: 0.4316 - val_accuracy: 0.8125
# Epoch 69/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4340 - accuracy: 0.8103 - val_loss: 0.4371 - val_accuracy: 0.8125
# Epoch 70/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4403 - accuracy: 0.7979 - val_loss: 0.4290 - val_accuracy: 0.7969
# Epoch 71/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4088 - accuracy: 0.8286 - val_loss: 0.4387 - val_accuracy: 0.8021
# Epoch 72/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4449 - accuracy: 0.7966 - val_loss: 0.4384 - val_accuracy: 0.8021
# Epoch 73/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4382 - accuracy: 0.8082 - val_loss: 0.4254 - val_accuracy: 0.8073
# Epoch 74/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3946 - accuracy: 0.8385 - val_loss: 0.4331 - val_accuracy: 0.7917
# Epoch 75/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3921 - accuracy: 0.8442 - val_loss: 0.4285 - val_accuracy: 0.8073
# Epoch 76/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4578 - accuracy: 0.8016 - val_loss: 0.4290 - val_accuracy: 0.8021
# Epoch 77/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4002 - accuracy: 0.8304 - val_loss: 0.4378 - val_accuracy: 0.8021
# Epoch 78/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4067 - accuracy: 0.8237 - val_loss: 0.4260 - val_accuracy: 0.8021
# Epoch 79/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4007 - accuracy: 0.8254 - val_loss: 0.4239 - val_accuracy: 0.8073
# Epoch 80/100
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8370 - val_loss: 0.4144 - val_accuracy: 0.8073
# Epoch 81/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3679 - accuracy: 0.8494 - val_loss: 0.4279 - val_accuracy: 0.8021
# Epoch 82/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4019 - accuracy: 0.8274 - val_loss: 0.4200 - val_accuracy: 0.8073
# Epoch 83/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4414 - accuracy: 0.7870 - val_loss: 0.4213 - val_accuracy: 0.8073
# Epoch 84/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3880 - accuracy: 0.8294 - val_loss: 0.4179 - val_accuracy: 0.8125
# Epoch 85/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4056 - accuracy: 0.8270 - val_loss: 0.4235 - val_accuracy: 0.8073
# Epoch 86/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4232 - accuracy: 0.8183 - val_loss: 0.4208 - val_accuracy: 0.8125
# Epoch 87/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4062 - accuracy: 0.8174 - val_loss: 0.4222 - val_accuracy: 0.7917
# Epoch 88/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4050 - accuracy: 0.8261 - val_loss: 0.4228 - val_accuracy: 0.8073
# Epoch 89/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3690 - accuracy: 0.8436 - val_loss: 0.4197 - val_accuracy: 0.7969
# Epoch 90/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3745 - accuracy: 0.8436 - val_loss: 0.4195 - val_accuracy: 0.7969
# Epoch 91/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3443 - accuracy: 0.8668 - val_loss: 0.4139 - val_accuracy: 0.7969
# Epoch 92/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3713 - accuracy: 0.8375 - val_loss: 0.4129 - val_accuracy: 0.8073
# Epoch 93/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4081 - accuracy: 0.8171 - val_loss: 0.4196 - val_accuracy: 0.8021
# Epoch 94/100
# 192/192 [==============================] - 1s 5ms/step - loss: 0.4168 - accuracy: 0.8019 - val_loss: 0.4170 - val_accuracy: 0.7969
# Epoch 95/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3633 - accuracy: 0.8561 - val_loss: 0.4212 - val_accuracy: 0.8021
# Epoch 96/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3892 - accuracy: 0.8151 - val_loss: 0.4106 - val_accuracy: 0.8073
# Epoch 97/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3830 - accuracy: 0.8313 - val_loss: 0.4132 - val_accuracy: 0.8229
# Epoch 98/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3714 - accuracy: 0.8345 - val_loss: 0.4165 - val_accuracy: 0.8125
# Epoch 99/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4333 - accuracy: 0.7940 - val_loss: 0.4152 - val_accuracy: 0.8021
# Epoch 100/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3863 - accuracy: 0.8368 - val_loss: 0.4145 - val_accuracy: 0.8021
