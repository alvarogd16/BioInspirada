# %% [markdown]
# ANN Binaria con dataset Tic-tac-toe

# %%
# Funciones para el procesamiento de los datos

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
Min_Max = preprocessing.MinMaxScaler()
Ordinal =preprocessing.OrdinalEncoder()


def one_hot_cols(df,cols_to_one):
    one_hot=pd.get_dummies(df,cols_to_one,columns=cols_to_one)
    return one_hot


def fit_cols(df, cols_to_fit,fit_function ):
    for col in cols_to_fit:
        df[col] = pd.DataFrame(fit_function.fit_transform(pd.DataFrame(df[col])),columns=[col])
    return df


def split_Dataset(mypandas, cols_for_Y,size=0.2,state=1):
    
    X =  mypandas.drop(cols_for_Y, axis=1)
    Y = mypandas[cols_for_Y]
    X.head()
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=size, random_state=state)
    return X_train.to_numpy(), X_test.to_numpy(), Y_train.to_numpy(), Y_test.to_numpy()

# %%
data_origin = pd.read_csv(r'../3_Normalización/datasets/tic_tac_toe_dataset.csv')
dataset = fit_cols(data_origin, list(data_origin.columns), Ordinal)
dataset = fit_cols(dataset, dataset.columns, Min_Max)
# dataset.head(20)

# %%
X_train, X_test, Y_train, Y_test = split_Dataset(dataset,['class'])
print(np.shape(X_train),np.shape(Y_train))
print(np.shape(X_test),np.shape(Y_test))
# Out:
# (766, 9) (766, 1)
# (192, 9) (192, 1)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.python.keras.utils import np_utils
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop


import matplotlib.pyplot as plt


def Show_History(History):
    # summarize history for accuracy
    plt.plot(History.history['accuracy'])
    plt.plot(History.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(History.history['loss'])
    plt.plot(History.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

np.random.seed(7)



Adam=optimizers.Adam(lr=0.05)
Sgd=optimizers.SGD(lr=0.01)

# %%
# Primer modelo
# accuracy 86% val 82% (epochs 100, bach_size 4)
# accuracy 88% val 85% (epochs 100, bach_size 1)
# Bastante overfitting
def Model1():
    model = Sequential()
    model.add(Dense(15,input_dim=9,activation='relu'))
    model.add(Dense(8,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Añadimos una capa dropout para intentar paliarlo
# accuracy 89% val 90% (epochs 100, bach_size 1) 
# La validación ha sido un pico (la epoca anterior tenia acc 91, val 85)
def Model2():
    model = Sequential()
    model.add(Dense(15,input_dim=9,activation='relu'))
    model.add(Dense(8,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Cambiamos el modelo para intentar obtener mejores resultados
# Vamos a probar con un modelo más simple
# accuracy 77% (epochs 100, bach_size 1) 
# accuracy 73% val 75% (epochs 200, bach_size 1)
# No es muy buen modelo
def Model3():
    model = Sequential()
    model.add(Dense(6,input_dim=9,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Hacemos una modificación del primer modelo bajando el número de neuronas por capa con la capa dropout
def Model4():
    model = Sequential()
    model.add(Dense(12,input_dim=9,activation='relu'))
    model.add(Dense(6,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

M=Model4()

# %%
History=M.fit(X_train, Y_train, epochs=100, batch_size=4, validation_data=(X_test,Y_test))
Show_History(History)
# Out:
# Epoch 1/100
# 192/192 [==============================] - 0s 1ms/step - loss: 0.6803 - accuracy: 0.5700 - val_loss: 0.6518 - val_accuracy: 0.6510
# Epoch 2/100
# 192/192 [==============================] - 0s 708us/step - loss: 0.6331 - accuracy: 0.6765 - val_loss: 0.6379 - val_accuracy: 0.6510
# Epoch 3/100
# 192/192 [==============================] - 0s 738us/step - loss: 0.6386 - accuracy: 0.6605 - val_loss: 0.6245 - val_accuracy: 0.6510
# Epoch 4/100
# 192/192 [==============================] - 0s 688us/step - loss: 0.6249 - accuracy: 0.6586 - val_loss: 0.6151 - val_accuracy: 0.6510
# Epoch 5/100
# 192/192 [==============================] - 0s 683us/step - loss: 0.6176 - accuracy: 0.6522 - val_loss: 0.6066 - val_accuracy: 0.6510
# Epoch 6/100
# 192/192 [==============================] - 0s 764us/step - loss: 0.6055 - accuracy: 0.6703 - val_loss: 0.5988 - val_accuracy: 0.6510
# Epoch 7/100
# 192/192 [==============================] - 0s 719us/step - loss: 0.5986 - accuracy: 0.6897 - val_loss: 0.5915 - val_accuracy: 0.6771
# Epoch 8/100
# 192/192 [==============================] - 0s 687us/step - loss: 0.5977 - accuracy: 0.6974 - val_loss: 0.5898 - val_accuracy: 0.6615
# Epoch 9/100
# 192/192 [==============================] - 0s 794us/step - loss: 0.6143 - accuracy: 0.6500 - val_loss: 0.5822 - val_accuracy: 0.6771
# Epoch 10/100
# 192/192 [==============================] - 0s 768us/step - loss: 0.6294 - accuracy: 0.6566 - val_loss: 0.5760 - val_accuracy: 0.6771
# Epoch 11/100
# 192/192 [==============================] - 0s 729us/step - loss: 0.5978 - accuracy: 0.6688 - val_loss: 0.5642 - val_accuracy: 0.6823
# Epoch 12/100
# 192/192 [==============================] - 0s 681us/step - loss: 0.6087 - accuracy: 0.6540 - val_loss: 0.5594 - val_accuracy: 0.7031
# Epoch 13/100
# 192/192 [==============================] - 0s 729us/step - loss: 0.5887 - accuracy: 0.6695 - val_loss: 0.5562 - val_accuracy: 0.7188
# Epoch 14/100
# 192/192 [==============================] - 0s 744us/step - loss: 0.5913 - accuracy: 0.6942 - val_loss: 0.5506 - val_accuracy: 0.7604
# Epoch 15/100
# 192/192 [==============================] - 0s 741us/step - loss: 0.5676 - accuracy: 0.7064 - val_loss: 0.5527 - val_accuracy: 0.7552
# Epoch 16/100
# 192/192 [==============================] - 0s 715us/step - loss: 0.5709 - accuracy: 0.7060 - val_loss: 0.5435 - val_accuracy: 0.7292
# Epoch 17/100
# 192/192 [==============================] - 0s 842us/step - loss: 0.5819 - accuracy: 0.6995 - val_loss: 0.5380 - val_accuracy: 0.7188
# Epoch 18/100
# 192/192 [==============================] - 0s 755us/step - loss: 0.5577 - accuracy: 0.7079 - val_loss: 0.5323 - val_accuracy: 0.7604
# Epoch 19/100
# 192/192 [==============================] - 0s 717us/step - loss: 0.5426 - accuracy: 0.7106 - val_loss: 0.5250 - val_accuracy: 0.7604
# Epoch 20/100
# 192/192 [==============================] - 0s 748us/step - loss: 0.5511 - accuracy: 0.7265 - val_loss: 0.5219 - val_accuracy: 0.7760
# Epoch 21/100
# 192/192 [==============================] - 0s 704us/step - loss: 0.5401 - accuracy: 0.7502 - val_loss: 0.5212 - val_accuracy: 0.7656
# Epoch 22/100
# 192/192 [==============================] - 0s 734us/step - loss: 0.5437 - accuracy: 0.7349 - val_loss: 0.5238 - val_accuracy: 0.7448
# Epoch 23/100
# 192/192 [==============================] - 0s 692us/step - loss: 0.5641 - accuracy: 0.7141 - val_loss: 0.5190 - val_accuracy: 0.7604
# Epoch 24/100
# 192/192 [==============================] - 0s 713us/step - loss: 0.5536 - accuracy: 0.7220 - val_loss: 0.5179 - val_accuracy: 0.7552
# Epoch 25/100
# 192/192 [==============================] - 0s 734us/step - loss: 0.5195 - accuracy: 0.7402 - val_loss: 0.5132 - val_accuracy: 0.7604
# Epoch 26/100
# 192/192 [==============================] - 0s 735us/step - loss: 0.5128 - accuracy: 0.7421 - val_loss: 0.5046 - val_accuracy: 0.7656
# Epoch 27/100
# 192/192 [==============================] - 0s 753us/step - loss: 0.5360 - accuracy: 0.7259 - val_loss: 0.5028 - val_accuracy: 0.7865
# Epoch 28/100
# 192/192 [==============================] - 0s 798us/step - loss: 0.5425 - accuracy: 0.7268 - val_loss: 0.5009 - val_accuracy: 0.7552
# Epoch 29/100
# 192/192 [==============================] - 0s 781us/step - loss: 0.5497 - accuracy: 0.6975 - val_loss: 0.5024 - val_accuracy: 0.7604
# Epoch 30/100
# 192/192 [==============================] - 0s 742us/step - loss: 0.5314 - accuracy: 0.7437 - val_loss: 0.5027 - val_accuracy: 0.7500
# Epoch 31/100
# 192/192 [==============================] - 0s 802us/step - loss: 0.5289 - accuracy: 0.7502 - val_loss: 0.5016 - val_accuracy: 0.7500
# Epoch 32/100
# 192/192 [==============================] - 0s 730us/step - loss: 0.5257 - accuracy: 0.7392 - val_loss: 0.4985 - val_accuracy: 0.8021
# Epoch 33/100
# 192/192 [==============================] - 0s 668us/step - loss: 0.5020 - accuracy: 0.7631 - val_loss: 0.4905 - val_accuracy: 0.7708
# Epoch 34/100
# 192/192 [==============================] - 0s 682us/step - loss: 0.5443 - accuracy: 0.7046 - val_loss: 0.4897 - val_accuracy: 0.7760
# Epoch 35/100
# 192/192 [==============================] - 0s 701us/step - loss: 0.5102 - accuracy: 0.7499 - val_loss: 0.4844 - val_accuracy: 0.8021
# Epoch 36/100
# 192/192 [==============================] - 0s 769us/step - loss: 0.5039 - accuracy: 0.7536 - val_loss: 0.4893 - val_accuracy: 0.7760
# Epoch 37/100
# 192/192 [==============================] - 0s 697us/step - loss: 0.5260 - accuracy: 0.7270 - val_loss: 0.4868 - val_accuracy: 0.7656
# Epoch 38/100
# 192/192 [==============================] - 0s 771us/step - loss: 0.4974 - accuracy: 0.7467 - val_loss: 0.4894 - val_accuracy: 0.7708
# Epoch 39/100
# 192/192 [==============================] - 0s 772us/step - loss: 0.5221 - accuracy: 0.7361 - val_loss: 0.4910 - val_accuracy: 0.7500
# Epoch 40/100
# 192/192 [==============================] - 0s 816us/step - loss: 0.5051 - accuracy: 0.7488 - val_loss: 0.4868 - val_accuracy: 0.7656
# Epoch 41/100
# 192/192 [==============================] - 0s 771us/step - loss: 0.4788 - accuracy: 0.7845 - val_loss: 0.4795 - val_accuracy: 0.7760
# Epoch 42/100
# 192/192 [==============================] - 0s 794us/step - loss: 0.5008 - accuracy: 0.7569 - val_loss: 0.4817 - val_accuracy: 0.7760
# Epoch 43/100
# 192/192 [==============================] - 0s 741us/step - loss: 0.4827 - accuracy: 0.7830 - val_loss: 0.4805 - val_accuracy: 0.7812
# Epoch 44/100
# 192/192 [==============================] - 0s 685us/step - loss: 0.5205 - accuracy: 0.7198 - val_loss: 0.4820 - val_accuracy: 0.7865
# Epoch 45/100
# 192/192 [==============================] - 0s 690us/step - loss: 0.4904 - accuracy: 0.7477 - val_loss: 0.4732 - val_accuracy: 0.7917
# Epoch 46/100
# 192/192 [==============================] - 0s 682us/step - loss: 0.4876 - accuracy: 0.7782 - val_loss: 0.4769 - val_accuracy: 0.7812
# Epoch 47/100
# 192/192 [==============================] - 0s 674us/step - loss: 0.5129 - accuracy: 0.7373 - val_loss: 0.4791 - val_accuracy: 0.7708
# Epoch 48/100
# 192/192 [==============================] - 0s 646us/step - loss: 0.4885 - accuracy: 0.7703 - val_loss: 0.4796 - val_accuracy: 0.7917
# Epoch 49/100
# 192/192 [==============================] - 0s 707us/step - loss: 0.5146 - accuracy: 0.7585 - val_loss: 0.4744 - val_accuracy: 0.7969
# Epoch 50/100
# 192/192 [==============================] - 0s 759us/step - loss: 0.4853 - accuracy: 0.7710 - val_loss: 0.4746 - val_accuracy: 0.7865
# Epoch 51/100
# 192/192 [==============================] - 0s 767us/step - loss: 0.4745 - accuracy: 0.7751 - val_loss: 0.4799 - val_accuracy: 0.7708
# Epoch 52/100
# 192/192 [==============================] - 0s 654us/step - loss: 0.4787 - accuracy: 0.7858 - val_loss: 0.4729 - val_accuracy: 0.7708
# Epoch 53/100
# 192/192 [==============================] - 0s 703us/step - loss: 0.4922 - accuracy: 0.7567 - val_loss: 0.4641 - val_accuracy: 0.7917
# Epoch 54/100
# 192/192 [==============================] - 0s 752us/step - loss: 0.4916 - accuracy: 0.7574 - val_loss: 0.4595 - val_accuracy: 0.8125
# Epoch 55/100
# 192/192 [==============================] - 0s 782us/step - loss: 0.5048 - accuracy: 0.7567 - val_loss: 0.4587 - val_accuracy: 0.7865
# Epoch 56/100
# 192/192 [==============================] - 0s 777us/step - loss: 0.5030 - accuracy: 0.7330 - val_loss: 0.4575 - val_accuracy: 0.7917
# Epoch 57/100
# 192/192 [==============================] - 0s 752us/step - loss: 0.4863 - accuracy: 0.7581 - val_loss: 0.4654 - val_accuracy: 0.7917
# Epoch 58/100
# 192/192 [==============================] - 0s 685us/step - loss: 0.4646 - accuracy: 0.7756 - val_loss: 0.4490 - val_accuracy: 0.8125
# Epoch 59/100
# 192/192 [==============================] - 0s 755us/step - loss: 0.4730 - accuracy: 0.7780 - val_loss: 0.4532 - val_accuracy: 0.7865
# Epoch 60/100
# 192/192 [==============================] - 0s 805us/step - loss: 0.5132 - accuracy: 0.7444 - val_loss: 0.4579 - val_accuracy: 0.7760
# Epoch 61/100
# 192/192 [==============================] - 0s 686us/step - loss: 0.4716 - accuracy: 0.7684 - val_loss: 0.4576 - val_accuracy: 0.7865
# Epoch 62/100
# 192/192 [==============================] - 0s 714us/step - loss: 0.4769 - accuracy: 0.7629 - val_loss: 0.4536 - val_accuracy: 0.7760
# Epoch 63/100
# 192/192 [==============================] - 0s 762us/step - loss: 0.4348 - accuracy: 0.7958 - val_loss: 0.4485 - val_accuracy: 0.8073
# Epoch 64/100
# 192/192 [==============================] - 0s 705us/step - loss: 0.4670 - accuracy: 0.7868 - val_loss: 0.4484 - val_accuracy: 0.8125
# Epoch 65/100
# 192/192 [==============================] - 0s 696us/step - loss: 0.5050 - accuracy: 0.7503 - val_loss: 0.4488 - val_accuracy: 0.7812
# Epoch 66/100
# 192/192 [==============================] - 0s 730us/step - loss: 0.4627 - accuracy: 0.7782 - val_loss: 0.4427 - val_accuracy: 0.7812
# Epoch 67/100
# 192/192 [==============================] - 0s 697us/step - loss: 0.4818 - accuracy: 0.7712 - val_loss: 0.4477 - val_accuracy: 0.7865
# Epoch 68/100
# 192/192 [==============================] - 0s 679us/step - loss: 0.4851 - accuracy: 0.7660 - val_loss: 0.4465 - val_accuracy: 0.7969
# Epoch 69/100
# 192/192 [==============================] - 0s 754us/step - loss: 0.4531 - accuracy: 0.8070 - val_loss: 0.4462 - val_accuracy: 0.7969
# Epoch 70/100
# 192/192 [==============================] - 0s 655us/step - loss: 0.5079 - accuracy: 0.7479 - val_loss: 0.4472 - val_accuracy: 0.8125
# Epoch 71/100
# 192/192 [==============================] - 0s 707us/step - loss: 0.4977 - accuracy: 0.7445 - val_loss: 0.4412 - val_accuracy: 0.7969
# Epoch 72/100
# 192/192 [==============================] - 0s 747us/step - loss: 0.4696 - accuracy: 0.7607 - val_loss: 0.4385 - val_accuracy: 0.8073
# Epoch 73/100
# 192/192 [==============================] - 0s 698us/step - loss: 0.5015 - accuracy: 0.7523 - val_loss: 0.4416 - val_accuracy: 0.8073
# Epoch 74/100
# 192/192 [==============================] - 0s 748us/step - loss: 0.4596 - accuracy: 0.7641 - val_loss: 0.4419 - val_accuracy: 0.8021
# Epoch 75/100
# 192/192 [==============================] - 0s 745us/step - loss: 0.4803 - accuracy: 0.7624 - val_loss: 0.4385 - val_accuracy: 0.8125
# Epoch 76/100
# 192/192 [==============================] - 0s 677us/step - loss: 0.4839 - accuracy: 0.7372 - val_loss: 0.4354 - val_accuracy: 0.8021
# Epoch 77/100
# 192/192 [==============================] - 0s 702us/step - loss: 0.4905 - accuracy: 0.7565 - val_loss: 0.4501 - val_accuracy: 0.7969
# Epoch 78/100
# 192/192 [==============================] - 0s 752us/step - loss: 0.4926 - accuracy: 0.7454 - val_loss: 0.4424 - val_accuracy: 0.7812
# Epoch 79/100
# 192/192 [==============================] - 0s 682us/step - loss: 0.4393 - accuracy: 0.7784 - val_loss: 0.4482 - val_accuracy: 0.7656
# Epoch 80/100
# 192/192 [==============================] - 0s 685us/step - loss: 0.4399 - accuracy: 0.8085 - val_loss: 0.4396 - val_accuracy: 0.7812
# Epoch 81/100
# 192/192 [==============================] - 0s 671us/step - loss: 0.4721 - accuracy: 0.7804 - val_loss: 0.4368 - val_accuracy: 0.7917
# Epoch 82/100
# 192/192 [==============================] - 0s 700us/step - loss: 0.4649 - accuracy: 0.7731 - val_loss: 0.4413 - val_accuracy: 0.7865
# Epoch 83/100
# 192/192 [==============================] - 0s 682us/step - loss: 0.4742 - accuracy: 0.7692 - val_loss: 0.4234 - val_accuracy: 0.7917
# Epoch 84/100
# 192/192 [==============================] - 0s 681us/step - loss: 0.4905 - accuracy: 0.7663 - val_loss: 0.4267 - val_accuracy: 0.8125
# Epoch 85/100
# 192/192 [==============================] - 0s 686us/step - loss: 0.4898 - accuracy: 0.7599 - val_loss: 0.4336 - val_accuracy: 0.7812
# Epoch 86/100
# 192/192 [==============================] - 0s 690us/step - loss: 0.4692 - accuracy: 0.7728 - val_loss: 0.4236 - val_accuracy: 0.7917
# Epoch 87/100
# 192/192 [==============================] - 0s 700us/step - loss: 0.4674 - accuracy: 0.7809 - val_loss: 0.4206 - val_accuracy: 0.8021
# Epoch 88/100
# 192/192 [==============================] - 0s 693us/step - loss: 0.4610 - accuracy: 0.7809 - val_loss: 0.4213 - val_accuracy: 0.8229
# Epoch 89/100
# 192/192 [==============================] - 0s 720us/step - loss: 0.4290 - accuracy: 0.8024 - val_loss: 0.4338 - val_accuracy: 0.7917
# Epoch 90/100
# 192/192 [==============================] - 0s 682us/step - loss: 0.4380 - accuracy: 0.7924 - val_loss: 0.4275 - val_accuracy: 0.7760
# Epoch 91/100
# 192/192 [==============================] - 0s 684us/step - loss: 0.4425 - accuracy: 0.7970 - val_loss: 0.4298 - val_accuracy: 0.7760
# Epoch 92/100
# 192/192 [==============================] - 0s 739us/step - loss: 0.4796 - accuracy: 0.7838 - val_loss: 0.4161 - val_accuracy: 0.8125
# Epoch 93/100
# 192/192 [==============================] - 0s 695us/step - loss: 0.4470 - accuracy: 0.7719 - val_loss: 0.4207 - val_accuracy: 0.7708
# Epoch 94/100
# 192/192 [==============================] - 0s 626us/step - loss: 0.4575 - accuracy: 0.7918 - val_loss: 0.4092 - val_accuracy: 0.8021
# Epoch 95/100
# 192/192 [==============================] - 0s 724us/step - loss: 0.4278 - accuracy: 0.7999 - val_loss: 0.4077 - val_accuracy: 0.8073
# Epoch 96/100
# 192/192 [==============================] - 0s 694us/step - loss: 0.4534 - accuracy: 0.7727 - val_loss: 0.4168 - val_accuracy: 0.8021
# Epoch 97/100
# 192/192 [==============================] - 0s 703us/step - loss: 0.4496 - accuracy: 0.7836 - val_loss: 0.4216 - val_accuracy: 0.8021
# Epoch 98/100
# 192/192 [==============================] - 0s 707us/step - loss: 0.4887 - accuracy: 0.7551 - val_loss: 0.4257 - val_accuracy: 0.7969
# Epoch 99/100
# 192/192 [==============================] - 0s 693us/step - loss: 0.4268 - accuracy: 0.7819 - val_loss: 0.4133 - val_accuracy: 0.7865
# Epoch 100/100
# 192/192 [==============================] - 0s 663us/step - loss: 0.4711 - accuracy: 0.7811 - val_loss: 0.4130 - val_accuracy: 0.7760
