# %% [markdown]
# ANN Binaria con dataset Tic-tac-toe

# %%
# Funciones para el procesamiento de los datos

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
Min_Max = preprocessing.MinMaxScaler()
Ordinal =preprocessing.OrdinalEncoder()


def one_hot_cols(df,cols_to_one):
    one_hot=pd.get_dummies(df,cols_to_one,columns=cols_to_one)
    return one_hot


def fit_cols(df, cols_to_fit,fit_function ):
    for col in cols_to_fit:
        df[col] = pd.DataFrame(fit_function.fit_transform(pd.DataFrame(df[col])),columns=[col])
    return df


def split_Dataset(mypandas, cols_for_Y,size=0.2,state=1):
    
    X =  mypandas.drop(cols_for_Y, axis=1)
    Y = mypandas[cols_for_Y]
    X.head()
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=size, random_state=state)
    return X_train.to_numpy(), X_test.to_numpy(), Y_train.to_numpy(), Y_test.to_numpy()

# %%
data_origin = pd.read_csv(r'../3_Normalización/datasets/tic_tac_toe_dataset.csv')
dataset = fit_cols(data_origin, list(data_origin.columns), Ordinal)
dataset = fit_cols(dataset, dataset.columns, Min_Max)
# dataset.head(20)

# %%
X_train, X_test, Y_train, Y_test = split_Dataset(dataset,['class'])
print(np.shape(X_train),np.shape(Y_train))
print(np.shape(X_test),np.shape(Y_test))
# Out:
# (766, 9) (766, 1)
# (192, 9) (192, 1)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.python.keras.utils import np_utils
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop


import matplotlib.pyplot as plt


def Show_History(History):
    # summarize history for accuracy
    plt.plot(History.history['accuracy'])
    plt.plot(History.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(History.history['loss'])
    plt.plot(History.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

np.random.seed(7)



Adam=optimizers.Adam(lr=0.05)
Sgd=optimizers.SGD(lr=0.01)

# %%
def Model1():
    model = Sequential()
    model.add(Dense(20,input_dim=9,activation='relu'))
    model.add(Dense(15,activation='relu'))
    
    
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model



M=Model1()

# %%
History=M.fit(X_train,Y_train,
              epochs=60,
              batch_size=5,
              validation_data=(X_test,Y_test))

Show_History(History)
# Out:
# Epoch 1/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.8120 - val_loss: 0.4583 - val_accuracy: 0.7865
# Epoch 2/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4192 - accuracy: 0.8211 - val_loss: 0.4490 - val_accuracy: 0.7917
# Epoch 3/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4091 - accuracy: 0.8081 - val_loss: 0.4445 - val_accuracy: 0.7760
# Epoch 4/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8198 - val_loss: 0.4238 - val_accuracy: 0.7708
# Epoch 5/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.8290 - val_loss: 0.4282 - val_accuracy: 0.7604
# Epoch 6/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8329 - val_loss: 0.4147 - val_accuracy: 0.7917
# Epoch 7/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8420 - val_loss: 0.4080 - val_accuracy: 0.7969
# Epoch 8/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8420 - val_loss: 0.4067 - val_accuracy: 0.7917
# Epoch 9/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3593 - accuracy: 0.8394 - val_loss: 0.4027 - val_accuracy: 0.8125
# Epoch 10/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8460 - val_loss: 0.3918 - val_accuracy: 0.8021
# Epoch 11/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8499 - val_loss: 0.3962 - val_accuracy: 0.8073
# Epoch 12/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8551 - val_loss: 0.3945 - val_accuracy: 0.8073
# Epoch 13/60
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3393 - accuracy: 0.8564 - val_loss: 0.4009 - val_accuracy: 0.7917
# Epoch 14/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8460 - val_loss: 0.3913 - val_accuracy: 0.8073
# Epoch 15/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8603 - val_loss: 0.3913 - val_accuracy: 0.8333
# Epoch 16/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.8577 - val_loss: 0.3845 - val_accuracy: 0.8333
# Epoch 17/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.8603 - val_loss: 0.4130 - val_accuracy: 0.7969
# Epoch 18/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8629 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 19/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3199 - accuracy: 0.8616 - val_loss: 0.3783 - val_accuracy: 0.8073
# Epoch 20/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3198 - accuracy: 0.8655 - val_loss: 0.3705 - val_accuracy: 0.8385
# Epoch 21/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3166 - accuracy: 0.8681 - val_loss: 0.3706 - val_accuracy: 0.8281
# Epoch 22/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.8708 - val_loss: 0.3925 - val_accuracy: 0.7969
# Epoch 23/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3096 - accuracy: 0.8668 - val_loss: 0.3628 - val_accuracy: 0.8281
# Epoch 24/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3019 - accuracy: 0.8773 - val_loss: 0.3935 - val_accuracy: 0.8021
# Epoch 25/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2971 - accuracy: 0.8760 - val_loss: 0.3684 - val_accuracy: 0.8177
# Epoch 26/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3043 - accuracy: 0.8708 - val_loss: 0.3769 - val_accuracy: 0.8229
# Epoch 27/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2920 - accuracy: 0.8773 - val_loss: 0.3727 - val_accuracy: 0.8281
# Epoch 28/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2868 - accuracy: 0.8773 - val_loss: 0.4015 - val_accuracy: 0.8177
# Epoch 29/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2905 - accuracy: 0.8799 - val_loss: 0.3588 - val_accuracy: 0.8229
# Epoch 30/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2857 - accuracy: 0.8642 - val_loss: 0.4003 - val_accuracy: 0.7917
# Epoch 31/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.8890 - val_loss: 0.3714 - val_accuracy: 0.8385
# Epoch 32/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2805 - accuracy: 0.8773 - val_loss: 0.3536 - val_accuracy: 0.8333
# Epoch 33/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2757 - accuracy: 0.8877 - val_loss: 0.3622 - val_accuracy: 0.8490
# Epoch 34/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2848 - accuracy: 0.8773 - val_loss: 0.3519 - val_accuracy: 0.8333
# Epoch 35/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2802 - accuracy: 0.8851 - val_loss: 0.3668 - val_accuracy: 0.8021
# Epoch 36/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.8864 - val_loss: 0.3596 - val_accuracy: 0.8385
# Epoch 37/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.8903 - val_loss: 0.3597 - val_accuracy: 0.8385
# Epoch 38/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8812 - val_loss: 0.3400 - val_accuracy: 0.8542
# Epoch 39/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2694 - accuracy: 0.8903 - val_loss: 0.3577 - val_accuracy: 0.8229
# Epoch 40/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.8930 - val_loss: 0.3422 - val_accuracy: 0.8542
# Epoch 41/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8825 - val_loss: 0.3460 - val_accuracy: 0.8333
# Epoch 42/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2582 - accuracy: 0.9008 - val_loss: 0.3391 - val_accuracy: 0.8542
# Epoch 43/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2630 - accuracy: 0.8851 - val_loss: 0.3437 - val_accuracy: 0.8542
# Epoch 44/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.8969 - val_loss: 0.3573 - val_accuracy: 0.8385
# Epoch 45/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.8982 - val_loss: 0.3353 - val_accuracy: 0.8438
# Epoch 46/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.8982 - val_loss: 0.3526 - val_accuracy: 0.7969
# Epoch 47/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.8838 - val_loss: 0.3577 - val_accuracy: 0.8542
# Epoch 48/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.8956 - val_loss: 0.3755 - val_accuracy: 0.8333
# Epoch 49/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.8943 - val_loss: 0.3422 - val_accuracy: 0.8333
# Epoch 50/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2469 - accuracy: 0.8982 - val_loss: 0.3332 - val_accuracy: 0.8542
# Epoch 51/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2399 - accuracy: 0.9086 - val_loss: 0.3557 - val_accuracy: 0.8385
# Epoch 52/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.8956 - val_loss: 0.3485 - val_accuracy: 0.8229
# Epoch 53/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.8930 - val_loss: 0.4135 - val_accuracy: 0.8177
# Epoch 54/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2418 - accuracy: 0.9034 - val_loss: 0.3396 - val_accuracy: 0.8490
# Epoch 55/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9021 - val_loss: 0.3639 - val_accuracy: 0.8281
# Epoch 56/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2478 - accuracy: 0.8969 - val_loss: 0.3735 - val_accuracy: 0.8385
# Epoch 57/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2395 - accuracy: 0.9060 - val_loss: 0.3627 - val_accuracy: 0.8490
# Epoch 58/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2306 - accuracy: 0.9047 - val_loss: 0.3411 - val_accuracy: 0.8333
# Epoch 59/60
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2381 - accuracy: 0.8982 - val_loss: 0.3315 - val_accuracy: 0.8542
# Epoch 60/60
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2354 - accuracy: 0.9021 - val_loss: 0.3305 - val_accuracy: 0.8646
