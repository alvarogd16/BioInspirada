# %% [markdown]
# ### entrenando con mnist

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt


def Show_History(History):
    # summarize history for accuracy
    plt.plot(History.history['accuracy'])
    plt.plot(History.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(History.history['loss'])
    plt.plot(History.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(train_labels[i])
plt.show()

# %%
x_train =train_images/255.0
x_test =test_images/255.0

from tensorflow.keras.utils import to_categorical

y_train = to_categorical(train_labels, num_classes=10)
y_test = to_categorical(test_labels, num_classes=10)

# %%
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (60000, 28, 28)
# (60000, 10)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.python.keras.utils import np_utils
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop


def Model1():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))

    model.add(Dense(512, activation='relu' ))
    model.add(Dense(100, activation='relu' ))
    
    model.add(Dense(10, activation='softmax'))
 
    model.compile(loss='categorical_crossentropy',
                  optimizer='sgd',
                  metrics=['accuracy'])
    return model


def Model2():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))

    model.add(Dense(128, activation='relu' ))
    model.add(Dense(10, activation='softmax'))
 
    model.compile(loss='categorical_crossentropy',
                  optimizer='sgd',
                  metrics=['accuracy'])
    return model


M=Model2()
M.summary()
# Out:
# 2021-10-16 12:39:48.130830: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-16 12:39:48.178686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.178994: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:54:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2021-10-16 12:39:48.179162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-16 12:39:48.180494: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-16 12:39:48.182016: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-16 12:39:48.182194: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-16 12:39:48.183424: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-16 12:39:48.184189: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-16 12:39:48.186946: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-16 12:39:48.187054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.187372: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.187593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-10-16 12:39:48.188294: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-10-16 12:39:48.213509: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3792690000 Hz
# 2021-10-16 12:39:48.214338: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562f6ca975a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-16 12:39:48.214351: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-10-16 12:39:48.214481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.214730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:54:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2021-10-16 12:39:48.214755: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-16 12:39:48.214766: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-10-16 12:39:48.214775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-10-16 12:39:48.214784: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-10-16 12:39:48.214793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-10-16 12:39:48.214801: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-10-16 12:39:48.214810: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-16 12:39:48.214860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.215145: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.215399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-10-16 12:39:48.215430: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-16 12:39:48.263694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-16 12:39:48.263710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-10-16 12:39:48.263714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-10-16 12:39:48.263852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.264049: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.264233: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 12:39:48.264408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 45 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:54:00.0, compute capability: 7.5)
# 2021-10-16 12:39:48.265724: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562f6e018530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-10-16 12:39:48.265732: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce RTX 2080 Ti, Compute Capability 7.5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=M.fit(x_train, y_train,
          batch_size=100,
          epochs=40,validation_data=(x_test, y_test),
          verbose=1
          )
# Out:
# Epoch 1/40
#  52/600 [=>............................] - ETA: 0s - loss: 2.0978 - accuracy: 0.3244
# 2021-10-16 12:39:54.215962: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 600/600 [==============================] - 1s 1ms/step - loss: 1.0408 - accuracy: 0.7541 - val_loss: 0.5458 - val_accuracy: 0.8709
# Epoch 2/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.4889 - accuracy: 0.8745 - val_loss: 0.4073 - val_accuracy: 0.8923
# Epoch 3/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.4026 - accuracy: 0.8910 - val_loss: 0.3570 - val_accuracy: 0.9024
# Epoch 4/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8993 - val_loss: 0.3287 - val_accuracy: 0.9096
# Epoch 5/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.3377 - accuracy: 0.9059 - val_loss: 0.3099 - val_accuracy: 0.9144
# Epoch 6/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.3194 - accuracy: 0.9103 - val_loss: 0.2963 - val_accuracy: 0.9182
# Epoch 7/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.3052 - accuracy: 0.9136 - val_loss: 0.2844 - val_accuracy: 0.9223
# Epoch 8/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2931 - accuracy: 0.9172 - val_loss: 0.2755 - val_accuracy: 0.9242
# Epoch 9/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2824 - accuracy: 0.9213 - val_loss: 0.2651 - val_accuracy: 0.9260
# Epoch 10/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2732 - accuracy: 0.9239 - val_loss: 0.2570 - val_accuracy: 0.9284
# Epoch 11/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2645 - accuracy: 0.9259 - val_loss: 0.2507 - val_accuracy: 0.9298
# Epoch 12/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2568 - accuracy: 0.9279 - val_loss: 0.2433 - val_accuracy: 0.9320
# Epoch 13/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2494 - accuracy: 0.9306 - val_loss: 0.2377 - val_accuracy: 0.9331
# Epoch 14/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2427 - accuracy: 0.9323 - val_loss: 0.2310 - val_accuracy: 0.9355
# Epoch 15/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2361 - accuracy: 0.9345 - val_loss: 0.2256 - val_accuracy: 0.9370
# Epoch 16/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2301 - accuracy: 0.9358 - val_loss: 0.2211 - val_accuracy: 0.9376
# Epoch 17/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2244 - accuracy: 0.9376 - val_loss: 0.2168 - val_accuracy: 0.9395
# Epoch 18/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2190 - accuracy: 0.9388 - val_loss: 0.2112 - val_accuracy: 0.9409
# Epoch 19/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2139 - accuracy: 0.9404 - val_loss: 0.2067 - val_accuracy: 0.9427
# Epoch 20/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2090 - accuracy: 0.9415 - val_loss: 0.2033 - val_accuracy: 0.9427
# Epoch 21/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2043 - accuracy: 0.9430 - val_loss: 0.1988 - val_accuracy: 0.9437
# Epoch 22/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1997 - accuracy: 0.9439 - val_loss: 0.1950 - val_accuracy: 0.9443
# Epoch 23/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1954 - accuracy: 0.9453 - val_loss: 0.1909 - val_accuracy: 0.9452
# Epoch 24/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1912 - accuracy: 0.9465 - val_loss: 0.1884 - val_accuracy: 0.9465
# Epoch 25/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1873 - accuracy: 0.9474 - val_loss: 0.1832 - val_accuracy: 0.9479
# Epoch 26/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1834 - accuracy: 0.9487 - val_loss: 0.1801 - val_accuracy: 0.9484
# Epoch 27/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1798 - accuracy: 0.9497 - val_loss: 0.1771 - val_accuracy: 0.9494
# Epoch 28/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1764 - accuracy: 0.9508 - val_loss: 0.1741 - val_accuracy: 0.9505
# Epoch 29/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1729 - accuracy: 0.9516 - val_loss: 0.1718 - val_accuracy: 0.9504
# Epoch 30/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1696 - accuracy: 0.9525 - val_loss: 0.1682 - val_accuracy: 0.9516
# Epoch 31/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1666 - accuracy: 0.9536 - val_loss: 0.1657 - val_accuracy: 0.9521
# Epoch 32/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1636 - accuracy: 0.9543 - val_loss: 0.1633 - val_accuracy: 0.9529
# Epoch 33/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1606 - accuracy: 0.9553 - val_loss: 0.1621 - val_accuracy: 0.9534
# Epoch 34/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1579 - accuracy: 0.9561 - val_loss: 0.1583 - val_accuracy: 0.9544
# Epoch 35/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1550 - accuracy: 0.9569 - val_loss: 0.1566 - val_accuracy: 0.9543
# Epoch 36/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1525 - accuracy: 0.9576 - val_loss: 0.1541 - val_accuracy: 0.9549
# Epoch 37/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1500 - accuracy: 0.9582 - val_loss: 0.1519 - val_accuracy: 0.9561
# Epoch 38/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1475 - accuracy: 0.9592 - val_loss: 0.1505 - val_accuracy: 0.9559
# Epoch 39/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1452 - accuracy: 0.9598 - val_loss: 0.1477 - val_accuracy: 0.9567
# Epoch 40/40
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1429 - accuracy: 0.9603 - val_loss: 0.1463 - val_accuracy: 0.9567

# %%
Show_History(history)
