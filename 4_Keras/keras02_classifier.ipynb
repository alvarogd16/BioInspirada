# %% [markdown]
# ejemplo clasificacion keras churm_Modelling
#
#
# The Dataset: Bank Customer Churn Modeling

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
Min_Max = preprocessing.MinMaxScaler()
Ordinal =preprocessing.OrdinalEncoder()


def one_hot_cols(df,cols_to_one):
    one_hot=pd.get_dummies(df,cols_to_one,columns=cols_to_one)
    return one_hot


def fit_cols(df, cols_to_fit,fit_function ):
    for col in cols_to_fit:
        df[col] = pd.DataFrame(fit_function.fit_transform(pd.DataFrame(df[col])),columns=[col])
    return df


def split_Dataset(mypandas, cols_for_Y,size=0.2,state=1):
    
    X =  mypandas.drop(cols_for_Y, axis=1)
    Y = mypandas[cols_for_Y]
    X.head()
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=size, random_state=state)
    return X_train.to_numpy(), X_test.to_numpy(), Y_train.to_numpy(), Y_test.to_numpy()

# %%
data_origin = pd.read_csv(r'data/Churn_Modelling.csv')
dataset = data_origin.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
dataset= fit_cols(dataset,['Gender','Geography'],Ordinal)
dataset= fit_cols(dataset,dataset.columns,Min_Max)
dataset.head(20)
# Out:
#     CreditScore  Geography  Gender       Age  Tenure   Balance  NumOfProducts  \
# 0         0.538        0.0     0.0  0.324324     0.2  0.000000       0.000000
# 1         0.516        1.0     0.0  0.310811     0.1  0.334031       0.000000
# 2         0.304        0.0     0.0  0.324324     0.8  0.636357       0.666667
# 3         0.698        0.0     0.0  0.283784     0.1  0.000000       0.333333
# 4         1.000        1.0     0.0  0.337838     0.2  0.500246       0.000000
# 5         0.590        1.0     1.0  0.351351     0.8  0.453394       0.333333
# 6         0.944        0.0     1.0  0.432432     0.7  0.000000       0.333333
# 7         0.052        0.5     0.0  0.148649     0.4  0.458540       1.000000
# 8         0.302        0.0     1.0  0.351351     0.4  0.566170       0.333333
# 9         0.668        0.0     1.0  0.121622     0.2  0.536488       0.000000
# 10        0.356        0.0     1.0  0.175676     0.6  0.406606       0.333333
# 11        0.294        1.0     1.0  0.081081     0.3  0.000000       0.333333
# 12        0.252        0.0     0.0  0.216216     1.0  0.000000       0.333333
# 13        0.398        0.0     0.0  0.094595     0.5  0.000000       0.333333
# 14        0.570        1.0     0.0  0.229730     0.7  0.000000       0.333333
# 15        0.532        0.5     1.0  0.364865     0.3  0.570468       0.333333
# 16        0.606        0.5     1.0  0.540541     0.1  0.528513       0.000000
# 17        0.398        1.0     0.0  0.081081     0.9  0.000000       0.333333
# 18        0.474        1.0     1.0  0.364865     0.6  0.000000       0.000000
# 19        0.752        0.0     0.0  0.081081     0.6  0.000000       0.333333
#
#     HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0         1.0             1.0         0.506735     1.0
# 1         0.0             1.0         0.562709     0.0
# 2         1.0             0.0         0.569654     1.0
# 3         0.0             0.0         0.469120     0.0
# 4         1.0             1.0         0.395400     0.0
# 5         1.0             0.0         0.748797     1.0
# 6         1.0             1.0         0.050261     0.0
# 7         1.0             0.0         0.596733     1.0
# 8         0.0             1.0         0.374680     0.0
# 9         1.0             1.0         0.358605     0.0
# 10        0.0             0.0         0.400886     0.0
# 11        1.0             0.0         0.381929     0.0
# 12        1.0             0.0         0.131260     0.0
# 13        0.0             0.0         0.954322     0.0
# 14        1.0             1.0         0.329732     0.0
# 15        0.0             1.0         0.321609     0.0
# 16        1.0             0.0         0.025433     1.0
# 17        1.0             1.0         0.071981     0.0
# 18        0.0             0.0         0.793442     0.0
# 19        1.0             1.0         0.273588     0.0

# %%
X_train, X_test, Y_train, Y_test = split_Dataset(dataset,['Exited'])
print(np.shape(X_train),np.shape(Y_train))
print(np.shape(X_test),np.shape(Y_test))
# Out:
# (8000, 10) (8000, 1)
# (2000, 10) (2000, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import initializers
import matplotlib.pyplot as plt


def Show_History(History):
    # summarize history for accuracy
    plt.plot(History.history['accuracy'])
    plt.plot(History.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(History.history['loss'])
    plt.plot(History.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

np.random.seed(7)



Adam=optimizers.Adam(lr=0.05)
Sgd=optimizers.SGD(lr=0.01)

# %%
def Model1():
    model = Sequential()
    model.add(Dense(20,input_dim=10,activation='relu'))
    model.add(Dense(15,activation='relu'))
    
    
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model



M=Model1()

# %%
History=M.fit(X_train,Y_train,
              epochs=30,
              batch_size=5,
              validation_data=(X_test,Y_test))

Show_History(History)
# Out:
# Epoch 1/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3556 - accuracy: 0.8566 - val_loss: 0.3460 - val_accuracy: 0.8620
# Epoch 2/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3540 - accuracy: 0.8546 - val_loss: 0.3471 - val_accuracy: 0.8610
# Epoch 3/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3519 - accuracy: 0.8556 - val_loss: 0.3527 - val_accuracy: 0.8530
# Epoch 4/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3513 - accuracy: 0.8564 - val_loss: 0.3501 - val_accuracy: 0.8580
# Epoch 5/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3510 - accuracy: 0.8566 - val_loss: 0.3450 - val_accuracy: 0.8615
# Epoch 6/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3484 - accuracy: 0.8580 - val_loss: 0.3407 - val_accuracy: 0.8585
# Epoch 7/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3480 - accuracy: 0.8586 - val_loss: 0.3465 - val_accuracy: 0.8610
# Epoch 8/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3463 - accuracy: 0.8600 - val_loss: 0.3422 - val_accuracy: 0.8585
# Epoch 9/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3452 - accuracy: 0.8589 - val_loss: 0.3492 - val_accuracy: 0.8590
# Epoch 10/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3452 - accuracy: 0.8566 - val_loss: 0.3475 - val_accuracy: 0.8590
# Epoch 11/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3436 - accuracy: 0.8601 - val_loss: 0.3413 - val_accuracy: 0.8620
# Epoch 12/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3441 - accuracy: 0.8600 - val_loss: 0.3436 - val_accuracy: 0.8605
# Epoch 13/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3426 - accuracy: 0.8609 - val_loss: 0.3423 - val_accuracy: 0.8620
# Epoch 14/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3415 - accuracy: 0.8619 - val_loss: 0.3413 - val_accuracy: 0.8615
# Epoch 15/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3411 - accuracy: 0.8604 - val_loss: 0.3539 - val_accuracy: 0.8545
# Epoch 16/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3403 - accuracy: 0.8585 - val_loss: 0.3399 - val_accuracy: 0.8610
# Epoch 17/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3392 - accuracy: 0.8593 - val_loss: 0.3427 - val_accuracy: 0.8655
# Epoch 18/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3403 - accuracy: 0.8609 - val_loss: 0.3422 - val_accuracy: 0.8580
# Epoch 19/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3385 - accuracy: 0.8629 - val_loss: 0.3438 - val_accuracy: 0.8640
# Epoch 20/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3391 - accuracy: 0.8596 - val_loss: 0.3412 - val_accuracy: 0.8595
# Epoch 21/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3372 - accuracy: 0.8614 - val_loss: 0.3420 - val_accuracy: 0.8635
# Epoch 22/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3378 - accuracy: 0.8634 - val_loss: 0.3358 - val_accuracy: 0.8640
# Epoch 23/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3362 - accuracy: 0.8618 - val_loss: 0.3361 - val_accuracy: 0.8610
# Epoch 24/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3357 - accuracy: 0.8633 - val_loss: 0.3429 - val_accuracy: 0.8595
# Epoch 25/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3365 - accuracy: 0.8616 - val_loss: 0.3379 - val_accuracy: 0.8645
# Epoch 26/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3350 - accuracy: 0.8611 - val_loss: 0.3360 - val_accuracy: 0.8645
# Epoch 27/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3350 - accuracy: 0.8615 - val_loss: 0.3364 - val_accuracy: 0.8625
# Epoch 28/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3347 - accuracy: 0.8643 - val_loss: 0.3355 - val_accuracy: 0.8595
# Epoch 29/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3345 - accuracy: 0.8630 - val_loss: 0.3406 - val_accuracy: 0.8585
# Epoch 30/30
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.3342 - accuracy: 0.8648 - val_loss: 0.3416 - val_accuracy: 0.8570
